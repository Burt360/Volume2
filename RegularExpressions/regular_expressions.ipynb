# %%
# regular_expressions.py
"""Volume 3: Regular Expressions.
Nathan Schill
Section 2
Thurs. Feb. 23, 2023
"""

import re

# %%
# Problem 1
def prob1():
    """Compile and return a regular expression pattern object with the
    pattern string "python".

    Returns:
        (_sre.SRE_Pattern): a compiled regular expression pattern object.
    """
    # Return pattern object of 'python''
    return re.compile(r'python')

pattern = prob1()
print(bool(pattern.search('python')))
# Out:
# True

# %%
# Problem 2
def prob2():
    """Compile and return a regular expression pattern object that matches
    the string "^{@}(?)[%]{.}(*)[_]{&}$".

    Returns:
        (_sre.SRE_Pattern): a compiled regular expression pattern object.
    """
    # Return pattern object of expr
    expr = r'\^\{\@\}\(\?\)\[\%\]\{\.\}\(\*\)\[\_\]\{\&\}\$'
    return re.compile(expr)

target = r'^{@}(?)[%]{.}(*)[_]{&}$'
pattern = prob2()
print(bool(pattern.search(target)))
# Out:
# True

# %%
# Problem 3
def prob3():
    """Compile and return a regular expression pattern object that matches
    the following strings (and no other strings).

        Book store          Mattress store          Grocery store
        Book supplier       Mattress supplier       Grocery supplier

    Returns:
        (_sre.SRE_Pattern): a compiled regular expression pattern object.
    """
    # Return pattern object of expr
    expr = r'^(Book|Mattress|Grocery) (store|supplier)$'
    return re.compile(expr)

pattern = prob3()

targets = ['Book store', 'Mattress store', 'Grocery store',
           'Book supplier', 'Mattress supplier', 'Grocery supplier']
for target in targets:
    print(bool(pattern.search(target)), target)

print()

fake_targets = ['Book sstore', 'MMattress store', 'Grocery storee',
                'Booksupplier', 'Mattress  supplier', 'Grocesry supplier']
for target in fake_targets:
    print(bool(pattern.search(target)), target)
# Out:
# True Book store
# True Mattress store
# True Grocery store
# True Book supplier
# True Mattress supplier
# True Grocery supplier
#
# False Book sstore
# False MMattress store
# False Grocery storee
# False Booksupplier
# False Mattress  supplier
# False Grocesry supplier

# %%
# Problem 4
def prob4():
    """Compile and return a regular expression pattern object that matches
    any valid Python identifier.

    Returns:
        (_sre.SRE_Pattern): a compiled regular expression pattern object.
    """
    # Valid python identifier pattern
    pi = r'[_a-zA-z][_\w]*'

    # Real number pattern
    rn = r'\d+(\.\d+)'

    # Single-quote pattern
    qu = r"'[^']*'"

    # Complete pattern
    expr = fr"^{pi} *(= *{rn}|= *{qu}|= *{pi})?$"
    return re.compile(expr)

pattern = prob4()

targets = ["Mouse", "_num = 2.3", "arg_ = 'hey'", "__x__", "var24",
           "max=total", "string= ''", "num_guesses"]
fake_targets = ["3rats", "_num = 2.3.2", "arg_ = 'one'two", "sq(x)", " x",
                "max=2total", "is_4=(value==4)", "pattern = r'^one|two fish$'"]

for target in targets:
    print(f'{bool(pattern.search(target))}:', target)
print()
for target in fake_targets:
    print(f'{bool(pattern.search(target))}:', target)
# Out:
# True: Mouse
# True: _num = 2.3
# True: arg_ = 'hey'
# True: __x__
# True: var24
# True: max=total
# True: string= ''
# True: num_guesses
#
# False: 3rats
# False: _num = 2.3.2
# False: arg_ = 'one'two
# False: sq(x)
# False:  x
# False: max=2total
# False: is_4=(value==4)
# False: pattern = r'^one|two fish$'

# %%
s =\
"""
k, i, p = 999, 1, 0
while k > i
    i *= 2
    p += 1
    if k != 999
        61
        print("k should not have changed")
    else
        pass
    try
        pass
    except
        pass
    try
        pass
    except Exception as err
        pass
print(p)
"""

target =\
"""
k, i, p = 999, 1, 0
while k > i:
    i *= 2
    p += 1
    if k != 999:
        print("k should not have changed")
    else:
        pass
    try:
        pass
    except:
        pass
    try:
        pass
    except Exception as err:
        pass
print(p)
"""

# Problem 5
def prob5(code):
    """Use regular expressions to place colons in the appropriate spots of the
    input string, representing Python code. You may assume that every possible
    colon is missing in the input string.

    Parameters:
        code (str): a string of Python code without any colons.

    Returns:
        (str): code, but with the colons inserted in the right places.
    """

    # Keywords
    keywords = 'if', 'elif', 'for', 'while', 'with', 'def', 'class', 'except', 'else', 'finally', 'try'

    # Join keywords with pipes
    keywords = r'|'.join(keywords)
    
    # Add colons for keywords
    pattern = re.compile(fr'^(\s*?({keywords}).*)$', re.MULTILINE)
    code = pattern.sub(r'\1:', code)

    return code

print(s, prob5(s))
# Out:
# k, i, p = 999, 1, 0
# while k > i
#     i *= 2
#     p += 1
#     if k != 999
#         61
#         print("k should not have changed")
#     else
#         pass
#     try
#         pass
#     except
#         pass
#     try
#         pass
#     except Exception as err
#         pass
# print(p)
#
# k, i, p = 999, 1, 0
# while k > i:
#     i *= 2
#     p += 1
#     if k != 999:
#         61
#         print("k should not have changed")
#     else:
#         pass
#     try:
#         pass
#     except:
#         pass
#     try:
#         pass
#     except Exception as err:
#         pass
# print(p)

# %%
# Problem 6
def prob6(filename='fake_contacts.txt'):
    """Use regular expressions to parse the data in the given file and format
    it uniformly, writing birthdays as mm/dd/yyyy and phone numbers as
    (xxx)xxx-xxxx. Construct a dictionary where the key is the name of an
    individual and the value is another dictionary containing their
    information. Each of these inner dictionaries should have the keys
    "birthday", "email", and "phone". In the case of missing data, map the key
    to None.

    Returns:
        (dict): a dictionary mapping names to a dictionary of personal info.
    """
    
    # Create contacts dictionary, read file to string
    contacts = dict()
    with open(filename) as file:
        s = file.read()

    # Get names and store init entry in contacts dictionary
    name_expr = r'^([\.a-zA-Z ]*) '
    name_pat = re.compile(name_expr, re.MULTILINE)
    names = name_pat.findall(s)
    for name in names:
        contacts[name] = {'birthday':None, 'email':None, 'phone':None}

    # Get names and emails, and save emails
    email_expr = name_expr + r'.*?([\.\w]+@[\.\w]+)'
    email_pat = re.compile(email_expr, re.MULTILINE)
    names_emails = email_pat.findall(s)
    for name, email in names_emails:
        contacts[name]['email'] = email

    # Get names and phone numbers, and save phone numbers
    phone_expr = name_expr + r'.*?(\d\d\d)[\-\)]*(\d\d\d)[\-\(\)]*(\d\d\d\d)'
    phone_pat = re.compile(phone_expr, re.MULTILINE)
    names_phones = phone_pat.findall(s)
    for name, phone1, phone2, phone3 in names_phones:
        contacts[name]['phone'] = f'({phone1}){phone2}-{phone3}'

    # Get names and birthdays, and save birthdays
    bday_expr = name_expr + r'.*?(\d{1,2})[/](\d{1,2})[/](\d{2,4})'
    bday_pat = re.compile(bday_expr, re.MULTILINE)
    names_bdays = bday_pat.findall(s)
    for name, m, d, y in names_bdays:
        # If year has length 2, prepend '20'
        if len(y) == 2:
            y = '20' + y
        contacts[name]['birthday'] = f'{m.zfill(2)}/{d.zfill(2)}/{y}'
    
    return contacts

prob6()
# Out:
# {'John Doe': {'birthday': '01/01/2099',
#   'email': 'john_doe90@hopefullynotarealaddress.com',
#   'phone': '(123)456-7890'},
#  'Jane Smith': {'birthday': None, 'email': None, 'phone': '(222)111-3333'},
#  'Graiden T. Moses': {'birthday': '02/22/2058',
#   'email': 'vehicula_58@gravidaAliquamtincidunt.net',
#   'phone': '(287)610-0471'},
#  'Brock S. Schneider': {'birthday': '10/16/2069',
#   'email': 'sit@vulputateposuerevulputate.superfake.com',
#   'phone': '(483)928-1252'},
#  'Mary H. Hatfield': {'birthday': '10/16/2035',
#   'email': 'nisi.nibh.lacinia@lectus.fake.com',
#   'phone': '(430)750-4067'},
#  'Nora X. Sanchez': {'birthday': '07/23/2097',
#   'email': 'Ut@Aliquamerat.org',
#   'phone': '(998)918-1756'},
#  'Kennan H. Chen': {'birthday': '09/15/2057',
#   'email': 'amet.risus.Donec@elementumpurus.net',
#   'phone': '(908)747-7470'},
#  'Chaney Small': {'birthday': '05/20/2074',
#   'email': 'pellentesque.Sed@congueaaliquet.org',
#   'phone': '(544)665-0594'},
#  'Nola Daugherty': {'birthday': '10/06/2046',
#   'email': 'enim@Sed.superfake.com',
#   'phone': '(309)644-5235'},
#  'Kalia Valencia': {'birthday': '10/20/2048',
#   'email': 'lorem@metusIn.edu',
#   'phone': '(733)145-5928'},
#  'Mallory V. Stanley': {'birthday': '02/18/2057',
#   'email': 'Nullam@viverraMaecenas.superfake.com',
#   'phone': '(714)342-8282'},
#  'Marny Phillips': {'birthday': '03/14/2096',
#   'email': 'diam@sitamet.edu',
#   'phone': None},
#  'Cadman Mcgee': {'birthday': '06/28/2038',
#   'email': 'ullamcorper.eu.euismod_72@erosNamconsequat.superfake.com',
#   'phone': '(595)443-4836'},
#  'Emmanuel I. Gallegos': {'birthday': '07/02/2078',
#   'email': 'quis.arcu.vel@ascelerisquesed.edu',
#   'phone': '(110)234-6810'},
#  'Jesse C. Rivas': {'birthday': '12/18/2076',
#   'email': 'Curabitur.dictum@lectusquis.superfake.com',
#   'phone': '(733)470-1027'},
#  'Claudia Brennan': {'birthday': '01/10/2052',
#   'email': 'ipsum@Aenean.org',
#   'phone': '(351)471-0705'},
#  'Joshua T. Stanley': {'birthday': '11/08/2037',
#   'email': None,
#   'phone': '(384)441-3698'},
#  'Risa S. Pruitt': {'birthday': '06/27/2040',
#   'email': 'cursus.in@acturpis.edu',
#   'phone': '(151)387-5667'},
#  'Beau Mejia': {'birthday': '02/10/2080',
#   'email': None,
#   'phone': '(282)560-4397'},
#  'Keegan G. Mooney': {'birthday': '05/05/2067',
#   'email': 'egestas.Sed.pharetra@massa.fake.com',
#   'phone': '(567)160-7537'},
#  'Bradley G. Ferrell': {'birthday': '03/31/2092',
#   'email': 'semper_01@ultricesposuere.fake.com',
#   'phone': '(766)536-4432'},
#  'Jada G. Cain': {'birthday': '07/06/2096',
#   'email': 'nisl.Maecenas.malesuada@quis.org',
#   'phone': '(410)776-9692'},
#  'Fatima S. Hayden': {'birthday': '07/07/2075',
#   'email': 'in.sodales_54@elitsedconsequat.superfake.com',
#   'phone': '(812)661-5282'},
#  'Hop K. Griffith': {'birthday': '08/29/2082',
#   'email': 'elit.pharetra@facilisiSed.net',
#   'phone': '(193)479-8055'},
#  'Alfreda Z. White': {'birthday': '10/17/2034',
#   'email': 'quis.massa@CrasinterdumNunc.fake.com',
#   'phone': '(279)158-9015'},
#  'Sybil Mccormick': {'birthday': '04/07/2060',
#   'email': 'Phasellus.elit.pede@enimNuncut.net',
#   'phone': '(809)244-6092'},
#  'Elijah Jones': {'birthday': '07/20/2055',
#   'email': 'suscipit.est@nuncQuisqueornare.fake.com',
#   'phone': '(527)448-4406'},
#  'Daphne F. Dixon': {'birthday': '02/11/2082',
#   'email': 'eu.neque@facilisiSedneque.com',
#   'phone': '(602)249-7358'},
#  'Tamekah Morris': {'birthday': '03/13/2058',
#   'email': 'et@incursus.net',
#   'phone': '(834)200-7290'},
#  'Colton Hensley': {'birthday': '02/10/2048',
#   'email': 'ut.mi@idsapien.edu',
#   'phone': '(377)292-6902'},
#  'Dieter Reese': {'birthday': '09/26/2035',
#   'email': 'consectetuer.euismod.est@arcu.fake.com',
#   'phone': '(373)118-6964'},
#  'Xanthus Fletcher': {'birthday': '10/07/2034',
#   'email': 'vitae.risus.Duis@semperrutrumFusce.fake.com',
#   'phone': '(123)106-8873'},
#  'Clarke Hurley': {'birthday': '12/11/2076',
#   'email': 'sodales.elit.erat@nuncnulla.com',
#   'phone': '(440)776-8987'},
#  'Rebekah Vazquez': {'birthday': '01/30/2054',
#   'email': 'porttitor.tellus.non@sodales.superfake.com',
#   'phone': '(252)174-3311'},
#  'Cally Nelson': {'birthday': '05/30/2095',
#   'email': 'eget.laoreet@faucibuslectus.edu',
#   'phone': '(671)619-4335'},
#  'Kylynn W. Spears': {'birthday': '04/04/2048',
#   'email': 'vehicula.et.rutrum@sed.fake.com',
#   'phone': '(430)102-9006'},
#  'Kamal Blackburn': {'birthday': '06/20/2091',
#   'email': 'litora.torquent@Donecfringilla.org',
#   'phone': '(137)176-0943'},
#  'Tiger R. Glover': {'birthday': None,
#   'email': 'rutrum.urna@placerat.edu',
#   'phone': '(812)338-7337'},
#  'Jolie Potts': {'birthday': '12/27/2079',
#   'email': 'elit@Vivamusmolestie.com',
#   'phone': '(200)871-6808'},
#  'Xanthus C. Atkinson': {'birthday': '02/27/2096',
#   'email': 'lorem@Vestibulumante.org',
#   'phone': '(574)496-7415'},
#  'Stewart England': {'birthday': '08/16/2077',
#   'email': 'lobortis.risus@faucibuslectus.superfake.com',
#   'phone': '(344)841-1684'},
#  'Marshall Mcfadden': {'birthday': '03/24/2037',
#   'email': 'consectetuer.ipsum@pedenonummyut.fake.com',
#   'phone': '(680)705-8056'},
#  'Halee W. Hopper': {'birthday': '03/01/2061',
#   'email': 'sit.amet.ornare@nisl.org',
#   'phone': '(859)420-3351'},
#  'Oliver Wallace': {'birthday': '06/03/2095',
#   'email': 'dolor.Fusce.feugiat@ultrices.org',
#   'phone': '(265)982-3673'},
#  'Madison Burke': {'birthday': '12/24/2070',
#   'email': 'Aliquam.erat86_21@arcu.com',
#   'phone': '(467)100-9212'},
#  'Adele Rollins': {'birthday': '12/17/2079',
#   'email': 'lobortis.ultrices@disparturientmontes.edu',
#   'phone': '(242)240-0945'},
#  'Mohammad Slater': {'birthday': '09/28/2084',
#   'email': None,
#   'phone': '(247)526-1367'},
#  'Uriah Graham': {'birthday': '10/02/2062',
#   'email': 'lorem.lorem.luctus@IntegermollisInteger.fake.com',
#   'phone': '(431)886-2084'},
#  'Buckminster Robertson': {'birthday': '08/05/2099',
#   'email': 'tellus@elementumategestas.fake.com',
#   'phone': '(728)235-6373'},
#  'Rina O. Guthrie': {'birthday': '05/20/2074',
#   'email': 'fermentum.arcu.Vestibulum_20@aliquetvel.edu',
#   'phone': None},
#  'Anika K. Hogan': {'birthday': '06/24/2072',
#   'email': None,
#   'phone': '(370)582-6890'},
#  'Channing B. Spears': {'birthday': '07/14/2073',
#   'email': None,
#   'phone': '(789)974-4981'},
#  'Tyler U. Aguirre': {'birthday': '04/08/2055',
#   'email': 'tincidunt.vehicula_47@euturpis.superfake.com',
#   'phone': '(718)328-6845'},
#  'Inez Villarreal': {'birthday': '02/17/2075',
#   'email': 'adipiscing.elit.Curabitur@sit.net',
#   'phone': '(763)357-0975'},
#  'Carl Neal': {'birthday': '02/08/2048',
#   'email': 'faucibus.leo@semut.org',
#   'phone': '(213)444-9049'},
#  'Zia R. Casey': {'birthday': '11/29/2036',
#   'email': 'lobortis.risus.In@loremacrisus.fake.com',
#   'phone': '(266)986-9270'},
#  'Quynn K. Bernard': {'birthday': '02/01/2070',
#   'email': 'vehicula.aliquet.libero@Classaptent.superfake.com',
#   'phone': '(361)848-4639'},
#  'Stuart F. Durham': {'birthday': '11/27/2066',
#   'email': 'placerat.orci.lacus@eleifend.org',
#   'phone': '(770)778-5752'},
#  'Casey S. Elliott': {'birthday': '03/19/2058',
#   'email': 'lacus.Quisque@placerateget.fake.com',
#   'phone': '(972)152-4126'},
#  'Brielle R. Dorsey': {'birthday': '01/28/2050',
#   'email': 'elit@molestie.superfake.com',
#   'phone': '(411)617-9239'},
#  'Shay V. Romero': {'birthday': '06/23/2057',
#   'email': 'odio.Phasellus.at@urnanecluctus.edu',
#   'phone': '(871)750-2196'},
#  'Phillip S. Palmer': {'birthday': '09/27/2080',
#   'email': 'at@egetipsum.fake.com',
#   'phone': '(850)244-0832'},
#  'Dustin England': {'birthday': '12/14/2066',
#   'email': None,
#   'phone': '(385)877-0596'},
#  'Dakota Mckenzie': {'birthday': '02/13/2096',
#   'email': 'nisi.dictum@cursus.org',
#   'phone': None},
#  'Boris B. Stevens': {'birthday': '06/22/2055',
#   'email': 'Nullam.feugiat.placerat@ultricesDuis.fake.com',
#   'phone': '(427)938-9632'},
#  'Arden X. Gallagher': {'birthday': '02/11/2059',
#   'email': 'parturient.montes.nascetur_38@Maurisnulla.superfake.com',
#   'phone': '(666)445-1495'},
#  'Karina Calhoun': {'birthday': '06/29/2095',
#   'email': 'amet.consectetuer.adipiscing@aultriciesadipiscing.edu',
#   'phone': '(434)599-8120'},
#  'Elmo Durham': {'birthday': '09/10/2039',
#   'email': None,
#   'phone': '(285)266-6782'},
#  'Hector Durham': {'birthday': '03/26/2062',
#   'email': 'id@Cumsociis.superfake.com',
#   'phone': '(865)578-0183'},
#  'Matthew Goff': {'birthday': '07/29/2038',
#   'email': 'ante.dictum@aceleifendvitae.superfake.com',
#   'phone': '(631)253-4189'},
#  'Garth Potter': {'birthday': '10/10/2038',
#   'email': 'in.molestie@Etiamligulatortor.net',
#   'phone': '(224)278-2102'},
#  'Abdul Humphrey': {'birthday': '12/18/2061',
#   'email': 'posuere.vulputate@nuncrisus.org',
#   'phone': '(128)670-2752'},
#  'Selma J. Stanton': {'birthday': '05/28/2049',
#   'email': 'justo05@dolorsitamet.fake.com',
#   'phone': '(869)571-1117'},
#  'Palmer Ferrell': {'birthday': '12/09/2044',
#   'email': 'risus.Duis.a@Donec.fake.com',
#   'phone': '(579)165-6078'},
#  'Hyacinth Ramirez': {'birthday': '06/04/2098',
#   'email': 'Cum.sociis@Phasellusnulla.com',
#   'phone': '(580)205-8065'},
#  'Leroy V. Dejesus': {'birthday': '01/01/2084',
#   'email': 'eu@mi.org',
#   'phone': '(347)261-0767'},
#  'Jemima F. Leon': {'birthday': '08/27/2057',
#   'email': 'cursus.a@risus.com',
#   'phone': '(846)321-3389'},
#  'Taylor Henderson': {'birthday': '11/12/2093',
#   'email': None,
#   'phone': '(821)795-7911'},
#  'Garth J. Mccarthy': {'birthday': '06/13/2064',
#   'email': 'Aliquam.ultrices_31@sedpede.edu',
#   'phone': '(289)981-8616'},
#  'Martin R. Richmond': {'birthday': '07/17/2099',
#   'email': 'libero.est.congue97_48@Etiamlaoreetlibero.net',
#   'phone': None},
#  'Denton X. Fleming': {'birthday': '06/15/2098',
#   'email': 'eget.magna.Suspendisse@Nullamsuscipit.com',
#   'phone': '(447)342-4649'},
#  'George E. David': {'birthday': '02/06/2035',
#   'email': 'amet25@sitamet.fake.com',
#   'phone': '(416)992-7800'},
#  'Sarah Trujillo': {'birthday': '02/16/2075',
#   'email': 'Cras.vehicula@Duisami.com',
#   'phone': '(273)953-9363'},
#  'Marvin Adkins': {'birthday': '10/12/2044',
#   'email': 'sociosqu@Sednuncest.org',
#   'phone': '(255)197-0059'},
#  'Brennan Rocha': {'birthday': '12/16/2049',
#   'email': 'vel.faucibus@tristiquepellentesque.fake.com',
#   'phone': '(580)570-2416'},
#  'Ivana Padilla': {'birthday': '11/26/2089',
#   'email': 'Nam.porttitor.scelerisque@Proinnonmassa.edu',
#   'phone': '(640)677-3783'},
#  'Isaiah Wilkerson': {'birthday': '12/14/2044',
#   'email': 'dictum.eleifend.nunc@facilisislorem.superfake.com',
#   'phone': '(588)242-1263'},
#  'Lee D. Allison': {'birthday': '08/11/2044', 'email': None, 'phone': None},
#  'Dexter B. Decker': {'birthday': '04/16/2100',
#   'email': 'consequat@Praesentluctus.edu',
#   'phone': '(286)666-6833'},
#  'Ross Sparks': {'birthday': '10/23/2055',
#   'email': 'parturient.montes@mienim.edu',
#   'phone': '(133)152-5051'},
#  'Arthur D. Benton': {'birthday': '10/22/2032',
#   'email': 'lorem.ipsum@ligulatortordictum.fake.com',
#   'phone': '(412)786-7018'},
#  'Kermit Moody': {'birthday': '09/02/2094',
#   'email': None,
#   'phone': '(839)225-0197'},
#  'Yen Compton': {'birthday': '06/07/2038',
#   'email': 'mi.eleifend@ipsum.org',
#   'phone': '(261)436-1271'},
#  'Cruz Wilder': {'birthday': '03/22/2100',
#   'email': None,
#   'phone': '(288)435-5055'},
#  'Francesca Jacobson': {'birthday': '08/09/2048',
#   'email': 'Quisque.tincidunt.pede63@habitantmorbi.com',
#   'phone': '(745)902-8516'},
#  'Travis J. Kirk': {'birthday': '04/03/2066',
#   'email': 'vitae.orci.Phasellus@ametmassaQuisque.net',
#   'phone': '(409)609-4484'},
#  'Jared X. Lambert': {'birthday': '04/09/2061',
#   'email': None,
#   'phone': '(188)424-4584'},
#  'Jada F. Glenn': {'birthday': '01/07/2092',
#   'email': 'libero85@nec.superfake.com',
#   'phone': '(132)564-3692'},
#  'Simon Atkinson': {'birthday': '12/11/2099',
#   'email': 'ac@antedictum.edu',
#   'phone': '(421)372-3593'},
#  'Colt Evans': {'birthday': '01/07/2038',
#   'email': 'cursus.non.egestas@feugiattellus.net',
#   'phone': '(955)659-2830'},
#  'Shoshana Q. Booker': {'birthday': '12/30/2084',
#   'email': 'at@vulputaterisusa.org',
#   'phone': '(107)437-7081'},
#  'Urielle D. Gutierrez': {'birthday': '06/24/2032',
#   'email': 'elementum@mauris.com',
#   'phone': '(971)885-2881'},
#  'Sade N. Walter': {'birthday': '10/18/2078',
#   'email': None,
#   'phone': '(525)462-7801'},
#  'Stella Bolton': {'birthday': None,
#   'email': 'non.dapibus_31@amet.org',
#   'phone': '(952)572-5279'},
#  'David Sellers': {'birthday': '11/12/2047',
#   'email': 'enim@consectetuereuismodest.fake.com',
#   'phone': '(941)758-6788'},
#  'Ivor Shannon': {'birthday': '02/06/2067',
#   'email': 'Cras_62@rutrum.superfake.com',
#   'phone': '(294)631-3021'},
#  'Aidan Welch': {'birthday': '03/07/2088',
#   'email': 'ipsum.porta@interdumfeugiatSed.org',
#   'phone': '(537)207-0656'},
#  'Giselle Gallegos': {'birthday': '08/14/2069',
#   'email': 'ac.mattis.ornare98@Sedmalesuada.fake.com',
#   'phone': '(102)875-9951'},
#  'Gail B. Dale': {'birthday': '04/15/2067',
#   'email': 'Morbi.neque.tellus@tempor.com',
#   'phone': '(989)987-0620'},
#  'Marvin Joyce': {'birthday': '09/03/2083',
#   'email': 'Quisque@per.net',
#   'phone': '(269)772-2824'},
#  'Ciara Q. Chang': {'birthday': '09/18/2085',
#   'email': 'Duis@euenimEtiam.superfake.com',
#   'phone': '(704)737-7522'},
#  'Cedric M. Spence': {'birthday': '04/17/2052',
#   'email': 'Nulla.tempor@Fusce.edu',
#   'phone': '(216)947-4921'},
#  'Caryn Alford': {'birthday': '04/06/2057',
#   'email': 'Curabitur@noncursusnon.superfake.com',
#   'phone': '(936)902-2082'},
#  'Ryder S. Shields': {'birthday': '07/22/2076',
#   'email': 'Cum@disparturient.superfake.com',
#   'phone': '(594)577-9182'},
#  'Bernard Roach': {'birthday': None,
#   'email': 'Donec.feugiat.metus@et.edu',
#   'phone': '(200)247-3229'},
#  'Rajah B. Arnold': {'birthday': '12/06/2038',
#   'email': 'urna.nec@nibh.superfake.com',
#   'phone': '(827)744-0715'},
#  'Ima Roberson': {'birthday': '06/28/2036',
#   'email': 'fringilla.ornare62_12@CraspellentesqueSed.net',
#   'phone': None},
#  'Charde Fuller': {'birthday': '12/18/2052',
#   'email': None,
#   'phone': '(197)576-2172'},
#  'Ivor Baxter': {'birthday': None,
#   'email': 'ornare.Fusce.mollis@malesuadaiderat.superfake.com',
#   'phone': '(831)536-2369'},
#  'Leigh S. Medina': {'birthday': '11/29/2042',
#   'email': 'libero.Morbi.accumsan@euarcu.superfake.com',
#   'phone': '(620)715-8040'},
#  'Melanie Hess': {'birthday': '04/30/2033',
#   'email': 'metus.Aliquam@tincidunt.org',
#   'phone': '(413)700-5102'},
#  'Diana Atkins': {'birthday': '12/14/2089',
#   'email': 'cursus.et@consectetuercursuset.org',
#   'phone': None},
#  'Nathaniel J. Campbell': {'birthday': '06/17/2073',
#   'email': 'Aliquam.auctor01@dolorsit.fake.com',
#   'phone': '(784)663-8953'},
#  'Justin Hogan': {'birthday': '06/01/2041',
#   'email': 'auctor.velit_09@Nullamfeugiatplacerat.superfake.com',
#   'phone': '(133)554-0309'},
#  'Gail Stokes': {'birthday': '08/04/2080',
#   'email': 'nulla.In.tincidunt@utpellentesqueeget.net',
#   'phone': '(392)912-8159'},
#  'Mercedes P. Acosta': {'birthday': '09/01/2098',
#   'email': 'nisl.sem@nibhQuisque.superfake.com',
#   'phone': '(842)554-5196'},
#  'Mannix Murray': {'birthday': '11/08/2057',
#   'email': 'sem.ut@ante.superfake.com',
#   'phone': '(615)228-1433'},
#  'Zelenia Butler': {'birthday': '08/06/2070',
#   'email': 'commodo.hendrerit.Donec@tristiquesenectuset.net',
#   'phone': '(690)270-6723'},
#  'Geraldine Stone': {'birthday': '07/09/2044',
#   'email': 'accumsan.interdum@MaurisnullaInteger.fake.com',
#   'phone': '(943)248-8226'},
#  'Henry I. Sykes': {'birthday': '02/26/2039',
#   'email': 'ornare.placerat.orci@nisimagna.superfake.com',
#   'phone': '(382)847-9906'},
#  'Asher P. Mcmahon': {'birthday': None,
#   'email': 'feugiat@nibhenim.fake.com',
#   'phone': '(287)609-3622'},
#  'Mariam Z. Kirk': {'birthday': '07/02/2047',
#   'email': 'urna.Ut.tincidunt@lobortisauguescelerisque.superfake.com',
#   'phone': '(239)959-6456'},
#  'Quinn F. Henson': {'birthday': '01/18/2060',
#   'email': 'placerat@posuerecubilia.com',
#   'phone': '(257)849-0751'},
#  'Rudyard X. Humphrey': {'birthday': '07/02/2043',
#   'email': 'Maecenas@elitsedconsequat.org',
#   'phone': '(948)721-3913'},
#  'Gareth Ross': {'birthday': None,
#   'email': 'sodales@Sed.superfake.com',
#   'phone': '(461)503-6939'},
#  'Warren C. Flowers': {'birthday': '01/31/2033',
#   'email': 'sociosqu@eteuismod.fake.com',
#   'phone': '(436)871-3185'},
#  'Raya U. Landry': {'birthday': '04/29/2067',
#   'email': 'urna.justo@lectusquismassa.org',
#   'phone': '(307)820-4501'},
#  'Kennedy C. Gallagher': {'birthday': '12/04/2051',
#   'email': 'dolor.elit@necurna.com',
#   'phone': '(506)163-9655'},
#  'Darius G. Bradford': {'birthday': '11/11/2070',
#   'email': 'enim.Nunc@justo.com',
#   'phone': '(712)899-3002'},
#  'Channing S. Hale': {'birthday': '07/25/2065',
#   'email': 'Proin.vel@lectus.edu',
#   'phone': '(957)372-5981'},
#  'Iona House': {'birthday': '09/17/2037',
#   'email': 'et.magnis.dis@turpisIn.edu',
#   'phone': '(300)846-8646'},
#  'Xavier J. Merritt': {'birthday': '01/26/2070',
#   'email': None,
#   'phone': '(860)609-6643'},
#  'Brenden Alston': {'birthday': '07/12/2094',
#   'email': 'consectetuer@in.edu',
#   'phone': '(583)277-3768'},
#  'Aristotle Q. Velazquez': {'birthday': '04/06/2038',
#   'email': 'faucibus.lectus.a@Donecluctusaliquet.org',
#   'phone': '(963)296-5835'},
#  'Quyn Sullivan': {'birthday': '12/08/2042',
#   'email': 'posuere.enim.nisl@velturpisAliquam.fake.com',
#   'phone': None},
#  'Ulysses Z. Ruiz': {'birthday': '02/18/2061',
#   'email': 'arcu@tristique.fake.com',
#   'phone': '(648)589-0179'},
#  'Stacy Keith': {'birthday': '06/08/2055',
#   'email': 'et.netus.et@quis.com',
#   'phone': None},
#  'Oleg Y. Mccray': {'birthday': '11/04/2041',
#   'email': 'malesuada.fames.ac@Pellentesqueutipsum.edu',
#   'phone': '(111)389-5031'},
#  'Velma Russell': {'birthday': '12/13/2045',
#   'email': 'vulputate.lacus@neque.superfake.com',
#   'phone': '(149)280-5139'},
#  'Christine Fitzgerald': {'birthday': '06/08/2040',
#   'email': 'diam@primis.org',
#   'phone': '(391)980-6933'},
#  'Angela P. Talley': {'birthday': None,
#   'email': 'Phasellus.ornare.Fusce@convallis.fake.com',
#   'phone': '(762)537-7135'},
#  'Timothy Z. Melton': {'birthday': '03/26/2088',
#   'email': 'ipsum.Curabitur@risus.com',
#   'phone': '(278)216-7216'},
#  'Keefe H. Spence': {'birthday': '12/16/2037',
#   'email': 'et.pede@velit.superfake.com',
#   'phone': '(142)769-3891'},
#  'Stone Grant': {'birthday': '04/11/2032',
#   'email': 'mi@Maurisvestibulumneque.org',
#   'phone': '(145)174-4238'},
#  'Maile Coleman': {'birthday': '07/20/2089',
#   'email': 'sociis.natoque@sempertellusid.edu',
#   'phone': '(125)776-2980'},
#  'Baxter F. Chang': {'birthday': '02/28/2039',
#   'email': 'Maecenas@faucibusMorbi.superfake.com',
#   'phone': None},
#  'Faith O. Ayala': {'birthday': '04/16/2073',
#   'email': 'at@vitae.edu',
#   'phone': '(745)867-9756'},
#  'Jameson R. Camacho': {'birthday': '05/26/2062',
#   'email': 'facilisis.facilisis.magna@variusNamporttitor.net',
#   'phone': None},
#  'Joshua Jordan': {'birthday': '10/30/2049',
#   'email': 'felis_57@non.org',
#   'phone': '(270)507-0037'},
#  'Pascale A. Wynn': {'birthday': '01/30/2082',
#   'email': 'malesuada@atliberoMorbi.org',
#   'phone': '(384)196-1582'},
#  'Sawyer F. May': {'birthday': '11/08/2056',
#   'email': 'Cras.pellentesque.Sed@nislMaecenas.net',
#   'phone': '(586)767-7389'},
#  'Ivy F. Barrett': {'birthday': '03/06/2098',
#   'email': 'ipsum.non.arcu@sociis.org',
#   'phone': '(365)965-6003'},
#  'Miriam Glass': {'birthday': '10/25/2059',
#   'email': 'facilisis.non@Duisatlacus.com',
#   'phone': '(564)466-6729'},
#  'Jesse Guerrero': {'birthday': '12/17/2038',
#   'email': 'mattis.Integer@magnaNam.edu',
#   'phone': '(211)607-9463'},
#  'Amela E. Blankenship': {'birthday': '05/26/2092',
#   'email': 'elit.fermentum@Vestibulum.com',
#   'phone': '(562)124-2279'},
#  'Quamar Hale': {'birthday': '06/13/2082',
#   'email': 'risus.varius.orci94@hendrerit.superfake.com',
#   'phone': '(993)434-7737'},
#  'Barclay T. Wolfe': {'birthday': '03/01/2062',
#   'email': 'hendrerit.consectetuer@adipiscingnonluctus.com',
#   'phone': '(897)814-1254'},
#  'Rhea L. Bryan': {'birthday': '03/09/2094',
#   'email': 'pede05@loremtristique.com',
#   'phone': '(114)613-1009'},
#  'Kennan C. Barber': {'birthday': '02/25/2072',
#   'email': 'aliquet@scelerisque.net',
#   'phone': '(423)866-7422'},
#  'Marsden V. Steele': {'birthday': '06/25/2051',
#   'email': 'mauris@DonecegestasAliquam.net',
#   'phone': '(487)488-1513'},
#  'Wyoming V. Noel': {'birthday': '12/20/2039',
#   'email': 'Donec.egestas@euismodenim.org',
#   'phone': '(622)517-8500'},
#  'Ferdinand C. Donaldson': {'birthday': '05/07/2095',
#   'email': 'euismod_18@scelerisquenequesed.edu',
#   'phone': None},
#  'Abbot Morton': {'birthday': '04/05/2034',
#   'email': 'tellus.faucibus.leo25@telluseu.net',
#   'phone': '(984)965-3992'},
#  'Dexter Hill': {'birthday': '03/22/2077',
#   'email': 'pharetra.nibh@gravida.edu',
#   'phone': '(183)704-0598'},
#  'Rajah M. Wade': {'birthday': '09/13/2045',
#   'email': 'eget.ipsum@eratSed.superfake.com',
#   'phone': '(965)358-9171'},
#  'Brianna B. Hale': {'birthday': '04/21/2034',
#   'email': 'ultricies.ornare.elit@ametultricies.net',
#   'phone': '(903)593-2917'},
#  'Caleb Joseph': {'birthday': '04/26/2078',
#   'email': 'turpis46@quamquisdiam.fake.com',
#   'phone': '(532)603-0601'},
#  'Penelope Gonzalez': {'birthday': '10/23/2037',
#   'email': 'lorem.fringilla.ornare@vulputatevelit.edu',
#   'phone': '(299)830-9385'},
#  'Lucas S. Mcclure': {'birthday': '08/16/2079',
#   'email': 'mus.Proin@pharetra.org',
#   'phone': '(427)457-6416'},
#  'Gil G. Meyers': {'birthday': '05/06/2081',
#   'email': None,
#   'phone': '(197)407-7232'},
#  'Nerea Jarvis': {'birthday': '07/28/2038',
#   'email': 'adipiscing@tellus.com',
#   'phone': '(903)384-5464'},
#  'Mikayla Bradford': {'birthday': '01/28/2052',
#   'email': 'arcu.imperdiet.ullamcorper@purus.fake.com',
#   'phone': '(644)421-4882'},
#  'Lawrence J. Walton': {'birthday': '08/05/2085',
#   'email': 'consequat.auctor.nunc_69@elementumsemvitae.net',
#   'phone': '(573)894-2327'},
#  'Neil I. Morrow': {'birthday': '07/09/2059',
#   'email': None,
#   'phone': '(878)669-8827'},
#  'Madeson C. Cunningham': {'birthday': '01/11/2067',
#   'email': 'auctor@infaucibusorci.edu',
#   'phone': '(838)917-1330'},
#  'Fiona T. Hammond': {'birthday': '01/18/2093',
#   'email': 'Curabitur.sed@Seddiamlorem.superfake.com',
#   'phone': '(471)741-8951'},
#  'Seth B. Clayton': {'birthday': '01/05/2069',
#   'email': 'Nulla.dignissim@massa.superfake.com',
#   'phone': '(695)709-4514'},
#  'Magee Alvarez': {'birthday': '08/21/2052',
#   'email': 'ac.turpis48@Aliquamauctorvelit.net',
#   'phone': '(440)371-9599'},
#  'Kristen Davidson': {'birthday': '06/17/2094',
#   'email': 'cursus.et@sem.org',
#   'phone': '(992)941-9803'},
#  'Gabriel Zimmerman': {'birthday': '11/30/2081',
#   'email': 'morbi.tristique.senectus@Donecfringilla.net',
#   'phone': '(730)150-1616'},
#  'Carol B. Blevins': {'birthday': None,
#   'email': 'vel@vulputate.org',
#   'phone': None},
#  'Vladimir I. Nicholson': {'birthday': '06/09/2080',
#   'email': 'sem.ut.cursus@malesuadafames.superfake.com',
#   'phone': '(229)726-6189'},
#  'Demetria W. Neal': {'birthday': '09/23/2057',
#   'email': 'ac.metus.vitae@luctusipsum.superfake.com',
#   'phone': '(725)328-7370'},
#  'Shelby V. Levy': {'birthday': '04/06/2073',
#   'email': 'sagittis@Etiam.superfake.com',
#   'phone': '(455)522-2909'},
#  'Burke S. Cash': {'birthday': '07/13/2062',
#   'email': 'hendrerit.neque@seddolor.org',
#   'phone': '(537)594-7669'},
#  'Margaret Finch': {'birthday': '04/16/2075',
#   'email': 'amet.diam81@mauris.edu',
#   'phone': '(665)951-3349'},
#  'Camilla Richards': {'birthday': '05/13/2071',
#   'email': 'feugiat@non.org',
#   'phone': '(949)341-9661'},
#  'Grant K. Grimes': {'birthday': '06/23/2031',
#   'email': 'vel.pede.blandit_59@etmalesuadafames.com',
#   'phone': '(895)855-8054'},
#  'Rashad E. Washington': {'birthday': None,
#   'email': 'Donec.elementum@Duisacarcu.com',
#   'phone': '(138)518-8454'},
#  'Forrest Hinton': {'birthday': '06/30/2035',
#   'email': 'ultrices.posuere_57@tellusSuspendissesed.superfake.com',
#   'phone': None},
#  'Emily G. Dunlap': {'birthday': '11/19/2040',
#   'email': 'sit.amet.ante@elementumpurus.org',
#   'phone': '(552)329-9050'},
#  'Quin Rocha': {'birthday': '08/24/2064',
#   'email': 'ultrices.a@enimnec.net',
#   'phone': '(857)882-6371'},
#  'Amy T. Mcmillan': {'birthday': '12/03/2094',
#   'email': 'orci.in@Duismi.net',
#   'phone': '(473)300-2189'},
#  'Oren E. Kramer': {'birthday': '11/27/2074',
#   'email': 'mus.Aenean@interdumCurabitur.superfake.com',
#   'phone': '(454)407-2196'},
#  'Kane Stevens': {'birthday': '06/08/2081',
#   'email': 'non.bibendum@ornaresagittis.edu',
#   'phone': '(622)990-2707'},
#  'Kaitlin M. Ramirez': {'birthday': None,
#   'email': 'a.tortor@tinciduntduiaugue.com',
#   'phone': '(488)274-0893'},
#  'Rowan Vega': {'birthday': None,
#   'email': 'ullamcorper.nisl@congue.fake.com',
#   'phone': '(437)840-1165'},
#  'Kyle T. Monroe': {'birthday': '07/02/2061',
#   'email': 'ullamcorper.Duis@sem.com',
#   'phone': '(866)324-3114'},
#  'Ezra Espinoza': {'birthday': '04/16/2039',
#   'email': 'nulla.ante.iaculis@semNullainterdum.fake.com',
#   'phone': '(156)810-1726'},
#  'Ora Huff': {'birthday': '05/11/2086',
#   'email': 'id.blandit@etrutrumeu.net',
#   'phone': '(181)722-7807'},
#  'Mariko Perez': {'birthday': '03/21/2073',
#   'email': 'Ut@Sedmolestie.net',
#   'phone': '(573)340-3345'},
#  'Maggy Q. Callahan': {'birthday': '10/12/2051',
#   'email': 'nec.enim.Nunc_46@cursus.org',
#   'phone': '(333)712-1332'},
#  'Lance Terry': {'birthday': '07/24/2068',
#   'email': 'est.Nunc@acmattissemper.superfake.com',
#   'phone': '(392)457-5236'},
#  'Caldwell Knox': {'birthday': '06/02/2071',
#   'email': None,
#   'phone': '(228)526-2715'},
#  'Keely Sims': {'birthday': '11/26/2094',
#   'email': 'erat.nonummy.ultricies@anteiaculis.com',
#   'phone': '(780)788-1035'},
#  'Gray Stanton': {'birthday': '01/30/2071',
#   'email': 'pellentesque.eget43@non.org',
#   'phone': '(627)848-5277'},
#  'Dante Bird': {'birthday': '01/08/2066',
#   'email': 'convallis@rutrumurna.fake.com',
#   'phone': '(936)412-6919'},
#  'Eric N. Short': {'birthday': '06/02/2094',
#   'email': 'nec@per.com',
#   'phone': '(538)509-3113'},
#  'Judith F. Mcclain': {'birthday': '01/23/2060',
#   'email': 'urna@dapibusrutrum.fake.com',
#   'phone': '(223)729-5645'},
#  'Hayden Z. Harris': {'birthday': '08/25/2061',
#   'email': 'diam.dictum.sapien@varius.net',
#   'phone': '(192)904-4139'},
#  'Akeem P. Fernandez': {'birthday': '10/09/2037',
#   'email': 'orci.quis@sapiengravida.com',
#   'phone': '(838)557-1497'},
#  'Abel Kim': {'birthday': '05/23/2040',
#   'email': 'sed.pede@mauris.edu',
#   'phone': '(356)111-9452'},
#  'Sonya Beck': {'birthday': '06/13/2059',
#   'email': 'Donec@etlibero.fake.com',
#   'phone': None},
#  'Richard E. Sanders': {'birthday': '12/14/2054',
#   'email': 'scelerisque@euultricessit.edu',
#   'phone': '(602)260-4847'},
#  'Kyra Villarreal': {'birthday': '09/02/2033',
#   'email': 'Aliquam.vulputate.ullamcorper_67@accumsan.superfake.com',
#   'phone': '(116)389-1262'},
#  'Marshall Mejia': {'birthday': '07/26/2042',
#   'email': 'nisi.dictum.augue@molestie.org',
#   'phone': '(725)317-3849'},
#  'April B. Barton': {'birthday': '03/12/2041',
#   'email': 'nunc.sit@vulputate.org',
#   'phone': '(723)805-8255'},
#  'Taylor Reilly': {'birthday': '11/04/2079',
#   'email': 'et@pede.com',
#   'phone': None},
#  'Hillary H. Howe': {'birthday': '01/17/2049',
#   'email': 'amet09@estac.fake.com',
#   'phone': '(809)824-1020'},
#  'Yasir Carson': {'birthday': '01/13/2045',
#   'email': 'sem.Pellentesque.ut@velitin.net',
#   'phone': None},
#  'Jemima Hill': {'birthday': '11/08/2089',
#   'email': 'quam.quis61@ornaretortor.fake.com',
#   'phone': None},
#  'Benjamin Dean': {'birthday': '09/09/2033',
#   'email': 'Phasellus.nulla.Integer@incursus.com',
#   'phone': '(578)386-8241'},
#  'Kessie F. Downs': {'birthday': '11/12/2095',
#   'email': 'commodo@cursusaenim.superfake.com',
#   'phone': '(395)789-0594'},
#  'Hannah M. Dotson': {'birthday': '08/12/2091',
#   'email': 'augue.ut@Suspendissealiquet.net',
#   'phone': '(128)547-4349'},
#  'Kessie Contreras': {'birthday': '05/16/2068',
#   'email': 'Fusce14@gravidasit.edu',
#   'phone': '(146)627-9855'},
#  'Brittany Hood': {'birthday': '08/11/2068',
#   'email': 'arcu.Sed.et@Curabitur.net',
#   'phone': '(206)337-4807'},
#  'Reese K. Patel': {'birthday': '12/22/2087', 'email': None, 'phone': None},
#  'Salvador Morris': {'birthday': '10/23/2051',
#   'email': 'dui.semper@aliquamadipiscing.edu',
#   'phone': '(750)458-3296'},
#  'Kasimir B. Benson': {'birthday': '07/26/2050',
#   'email': 'dui.nec.urna@inlobortis.superfake.com',
#   'phone': '(899)465-5924'},
#  'Ira Wall': {'birthday': '03/04/2059',
#   'email': 'urna@mollisneccursus.fake.com',
#   'phone': '(299)883-7663'},
#  'Connor Ball': {'birthday': '12/13/2042',
#   'email': 'Quisque@Proinvelit.net',
#   'phone': '(866)389-4883'},
#  'Chancellor Holcomb': {'birthday': '10/01/2047',
#   'email': 'fermentum.convallis.ligula31@atpedeCras.org',
#   'phone': '(952)830-2463'},
#  'Quinlan Wise': {'birthday': '02/25/2080',
#   'email': 'sociis.natoque.penatibus@leoMorbi.com',
#   'phone': '(289)293-9770'},
#  'Amery Conway': {'birthday': '10/04/2050',
#   'email': 'quam.vel@magnaLorem.edu',
#   'phone': '(170)167-6899'},
#  'Zeus Ramos': {'birthday': '07/24/2092',
#   'email': 'sapien.gravida.non@a.fake.com',
#   'phone': '(415)568-6789'},
#  'Zenia Golden': {'birthday': '08/20/2041',
#   'email': 'diam.nunc@et.com',
#   'phone': '(456)228-0798'},
#  'Demetrius W. Ortiz': {'birthday': '02/08/2064',
#   'email': 'leo.Morbi@leoinlobortis.net',
#   'phone': '(603)230-8071'},
#  'Eaton Clayton': {'birthday': '05/14/2087',
#   'email': None,
#   'phone': '(282)429-0034'},
#  'Haviva Bowman': {'birthday': '11/20/2061',
#   'email': 'turpis@luctus.fake.com',
#   'phone': '(999)977-7744'},
#  'Keefe A. Richard': {'birthday': '10/08/2077',
#   'email': None,
#   'phone': '(375)211-2540'},
#  'Inez G. Nash': {'birthday': '12/18/2043',
#   'email': 'Cum.sociis@ligulaAeneangravida.fake.com',
#   'phone': '(279)951-1591'},
#  'Ciaran A. Raymond': {'birthday': '11/16/2070',
#   'email': 'ac@tellus.edu',
#   'phone': '(219)877-2491'},
#  'Raven H. Harrington': {'birthday': '07/17/2050',
#   'email': 'magna.Sed@gravidamolestiearcu.com',
#   'phone': '(319)933-1674'},
#  'Dominic Finley': {'birthday': None,
#   'email': 'vitae.erat@DonecfringillaDonec.org',
#   'phone': '(580)596-8580'},
#  'Sydnee Barron': {'birthday': '12/07/2061',
#   'email': 'ante.Maecenas43@egestasAliquamnec.net',
#   'phone': '(345)739-5757'},
#  'Ishmael Owen': {'birthday': '09/09/2073',
#   'email': 'commodo@felisorciadipiscing.org',
#   'phone': '(122)363-6369'},
#  'Shoshana Downs': {'birthday': '03/06/2099',
#   'email': 'hendrerit@nullaInteger.net',
#   'phone': '(504)440-1929'},
#  'Calvin Q. Vaughn': {'birthday': '03/28/2074',
#   'email': 'lectus.Nullam.suscipit@Vestibulum.net',
#   'phone': '(434)900-6365'},
#  'Raven G. Campbell': {'birthday': '05/02/2094',
#   'email': 'in.faucibus@lectuspedeultrices.fake.com',
#   'phone': '(310)914-5687'},
#  'Susan N. Norris': {'birthday': '05/12/2049',
#   'email': 'Ut.semper.pretium37@velest.fake.com',
#   'phone': '(449)193-7989'},
#  'Kristen Castro': {'birthday': '05/20/2052',
#   'email': None,
#   'phone': '(442)572-8217'},
#  'Herman G. Moses': {'birthday': '06/10/2044',
#   'email': 'urna.et@loremloremluctus.superfake.com',
#   'phone': '(380)691-3722'},
#  'Natalie Barron': {'birthday': '07/04/2052',
#   'email': 'libero.at_41@utdolordapibus.fake.com',
#   'phone': None},
#  'Fredericka F. Richmond': {'birthday': '02/17/2064',
#   'email': 'facilisis.eget@porttitortellusnon.net',
#   'phone': '(906)546-8074'},
#  'Quamar B. Adkins': {'birthday': '03/21/2078',
#   'email': 'sollicitudin.commodo.ipsum51@lacusvestibulum.edu',
#   'phone': '(418)545-5484'},
#  'Jackson R. Bender': {'birthday': '02/10/2053',
#   'email': 'dignissim.lacus.Aliquam@Nulladignissim.fake.com',
#   'phone': '(119)577-6383'},
#  'Edan Oneil': {'birthday': '02/04/2067',
#   'email': 'Aenean.euismod.mauris@utnulla.superfake.com',
#   'phone': '(591)490-4652'},
#  'Cassady Cooley': {'birthday': '09/03/2079',
#   'email': 'erat@Quisque.org',
#   'phone': '(336)429-7886'},
#  'Oliver Green': {'birthday': '12/14/2058',
#   'email': 'hendrerit08@nequeNullam.org',
#   'phone': None},
#  'Dacey Battle': {'birthday': '06/10/2067',
#   'email': 'egestas_79@arcuAliquam.net',
#   'phone': '(381)629-5607'},
#  'Jack C. Fisher': {'birthday': '11/11/2093',
#   'email': 'dui.in.sodales@eu.superfake.com',
#   'phone': '(402)618-4585'},
#  'Declan Baird': {'birthday': '01/25/2034',
#   'email': 'aliquam.arcu@eleifend.com',
#   'phone': '(942)302-2138'},
#  'Zenia Ayers': {'birthday': '05/10/2094',
#   'email': 'erat_30@tristiqueac.net',
#   'phone': '(756)882-3909'},
#  'Ayanna Grimes': {'birthday': '03/16/2051', 'email': None, 'phone': None},
#  'Cyrus G. Wiggins': {'birthday': '06/13/2072',
#   'email': 'pellentesque.a@urnajustofaucibus.com',
#   'phone': '(524)859-2679'},
#  'Tara Gilliam': {'birthday': '07/12/2046',
#   'email': 'nec.eleifend@eratvitaerisus.net',
#   'phone': '(962)782-5606'},
#  'Porter C. Atkinson': {'birthday': '08/05/2034',
#   'email': None,
#   'phone': '(912)977-4981'},
#  'Andrew O. Walls': {'birthday': '06/02/2064',
#   'email': 'tempor.diam@pede.com',
#   'phone': '(356)511-5486'},
#  'Florence N. Burt': {'birthday': '04/03/2045',
#   'email': 'eget.magna@vel.edu',
#   'phone': '(666)794-3078'},
#  'Ariana Blackwell': {'birthday': '02/15/2040',
#   'email': 'dictum.ultricies@ut.org',
#   'phone': '(144)117-0585'},
#  'Phyllis Humphrey': {'birthday': '01/24/2089',
#   'email': 'amet@gravidamaurisut.superfake.com',
#   'phone': '(642)839-8307'},
#  'Heidi Jarvis': {'birthday': '08/16/2100',
#   'email': 'mauris@sitamet.org',
#   'phone': '(575)885-3295'},
#  'Chaney R. Spears': {'birthday': '07/06/2062',
#   'email': 'suscipit03@massalobortisultrices.com',
#   'phone': '(461)676-4268'},
#  'Alma W. Green': {'birthday': '05/22/2100',
#   'email': 'lorem.lorem.luctus@intempuseu.com',
#   'phone': '(606)989-3198'},
#  'Jaquelyn V. Bean': {'birthday': '08/17/2095',
#   'email': 'amet.ante@Cras.org',
#   'phone': '(620)274-5799'},
#  'Maisie Y. Mcdonald': {'birthday': '11/05/2096',
#   'email': 'ac.metus.vitae@Lorem.edu',
#   'phone': '(749)350-7810'},
#  'Graiden E. Hicks': {'birthday': '03/15/2033',
#   'email': 'tristique.ac@feugiat.fake.com',
#   'phone': '(871)301-7873'},
#  'Hammett Kerr': {'birthday': '11/02/2094',
#   'email': 'pharetra.felis.eget@Duiscursusdiam.fake.com',
#   'phone': '(655)463-3591'},
#  'Charity H. Barrett': {'birthday': '09/28/2083',
#   'email': None,
#   'phone': '(124)675-8501'},
#  'Chaney Y. Barron': {'birthday': '11/20/2030',
#   'email': None,
#   'phone': '(716)894-9200'},
#  'Gisela Soto': {'birthday': '11/23/2061',
#   'email': 'ligula.Aenean.euismod_56@ante.net',
#   'phone': '(652)614-3549'},
#  'Dante N. Franks': {'birthday': '03/14/2051',
#   'email': 'dis.parturient.montes@Maecenas.edu',
#   'phone': '(707)695-7929'},
#  'Samuel F. Wheeler': {'birthday': '03/02/2059',
#   'email': 'sociis@metusIn.edu',
#   'phone': '(879)750-3528'},
#  'Len Sargent': {'birthday': '02/17/2088',
#   'email': 'enim.Curabitur@magnaDuisdignissim.com',
#   'phone': '(895)738-6111'},
#  'Leroy Crawford': {'birthday': '09/02/2033',
#   'email': 'lectus@Sed.org',
#   'phone': '(589)379-6594'},
#  'Blaine Dodson': {'birthday': '04/22/2076',
#   'email': None,
#   'phone': '(129)736-3405'},
#  'William Copeland': {'birthday': '10/12/2034',
#   'email': 'augue.id.ante@libero.net',
#   'phone': '(248)788-7587'},
#  'Keaton Cross': {'birthday': '02/14/2096',
#   'email': 'erat.volutpat.Nulla_04@tinciduntadipiscing.fake.com',
#   'phone': '(510)437-1478'},
#  'Samuel N. Rosario': {'birthday': '05/16/2036',
#   'email': 'sem.mollis@nonenimcommodo.fake.com',
#   'phone': '(389)133-7641'},
#  'Caleb Cardenas': {'birthday': '06/10/2083',
#   'email': 'in.felis@loremeumetus.superfake.com',
#   'phone': '(863)858-5429'},
#  'Brian Jarvis': {'birthday': '06/01/2048',
#   'email': 'nisl@lacusQuisquepurus.edu',
#   'phone': '(663)136-0370'},
#  'Urielle C. Daugherty': {'birthday': '12/06/2042',
#   'email': 'massa.Suspendisse.eleifend@augue.edu',
#   'phone': '(896)407-6026'},
#  'Kai Cochran': {'birthday': '05/19/2032',
#   'email': 'Nulla.tempor84@et.com',
#   'phone': '(985)618-0116'},
#  'Carla D. Randolph': {'birthday': None,
#   'email': 'accumsan.laoreet@consequat.edu',
#   'phone': '(128)265-3663'},
#  'Kyra C. Delacruz': {'birthday': '07/18/2081',
#   'email': 'Maecenas@Crasvehicula.net',
#   'phone': '(426)738-2514'},
#  'Bevis Jackson': {'birthday': '08/17/2077',
#   'email': 'id_83@est.edu',
#   'phone': None},
#  'Reuben Huffman': {'birthday': '03/12/2078',
#   'email': 'urna.justo@aceleifendvitae.fake.com',
#   'phone': '(877)600-9507'},
#  'Aubrey Bean': {'birthday': '03/04/2044',
#   'email': 'Nulla.dignissim.Maecenas@dapibusid.fake.com',
#   'phone': '(959)428-4588'},
#  'Blaine Cox': {'birthday': '07/19/2096',
#   'email': 'risus21_19@ornareegestasligula.net',
#   'phone': '(759)117-8317'},
#  'Rudyard Pruitt': {'birthday': '01/31/2041',
#   'email': 'dolor@nonvestibulumnec.edu',
#   'phone': '(294)596-1345'},
#  'Lester D. Lancaster': {'birthday': '05/05/2073',
#   'email': 'enim31@Nulla.org',
#   'phone': '(505)677-4055'},
#  'Rebecca U. Fulton': {'birthday': '08/24/2035',
#   'email': 'Etiam.vestibulum.massa@orci.edu',
#   'phone': '(514)194-1252'},
#  'Irma D. Arnold': {'birthday': '04/27/2099',
#   'email': 'Nunc.mauris@dictumaugue.org',
#   'phone': '(524)590-2590'},
#  'Ella T. Peterson': {'birthday': '09/21/2058',
#   'email': 'non.feugiat_08@turpisegestas.com',
#   'phone': '(986)121-6000'},
#  'Quentin K. Allen': {'birthday': None,
#   'email': 'et.ultrices@laoreet.fake.com',
#   'phone': '(710)421-4798'},
#  'Althea Montoya': {'birthday': '07/31/2046',
#   'email': 'eget.magna.Suspendisse@non.org',
#   'phone': '(679)794-4162'},
#  'Merritt E. Combs': {'birthday': None,
#   'email': 'eget@lectusantedictum.net',
#   'phone': '(616)332-5766'},
#  'Alika U. Clemons': {'birthday': None,
#   'email': 'vel@quispede.superfake.com',
#   'phone': '(870)275-5126'},
#  'Garth Roberts': {'birthday': '11/05/2081',
#   'email': 'odio.sagittis.semper@euismodestarcu.com',
#   'phone': '(515)837-1430'},
#  'Xantha S. Roy': {'birthday': '02/03/2081',
#   'email': 'iaculis@DonecnibhQuisque.superfake.com',
#   'phone': '(732)669-5761'},
#  'Iola Francis': {'birthday': '06/15/2073',
#   'email': 'risus.a.ultricies@pretium.edu',
#   'phone': '(649)236-0977'},
#  'Remedios Richardson': {'birthday': '11/09/2060',
#   'email': 'vel.mauris.Integer@purusin.org',
#   'phone': '(519)426-4008'},
#  'Rachel K. Knapp': {'birthday': '07/04/2065',
#   'email': 'Duis74@primis.fake.com',
#   'phone': '(546)252-7280'},
#  'Hannah I. Cantu': {'birthday': '07/23/2035',
#   'email': 'cursus@nuncrisus.org',
#   'phone': '(961)524-4447'},
#  'Nigel T. Mccarthy': {'birthday': '02/07/2066',
#   'email': 'erat@Aliquamtinciduntnunc.edu',
#   'phone': '(651)508-6430'},
#  'Carl R. Tran': {'birthday': '01/31/2037',
#   'email': 'metus@ac.com',
#   'phone': '(437)134-6428'},
#  'Valentine E. Webster': {'birthday': None,
#   'email': 'In.nec@interdumligula.superfake.com',
#   'phone': '(614)946-7953'},
#  'Quinlan V. Banks': {'birthday': None,
#   'email': 'aliquam.eu@porttitor.superfake.com',
#   'phone': '(615)308-4555'},
#  'Wade Nash': {'birthday': '08/09/2078',
#   'email': 'pede.Praesent@nibhdolor.fake.com',
#   'phone': '(492)367-7795'},
#  'Robert Pearson': {'birthday': None,
#   'email': 'Sed.congue_55@sit.org',
#   'phone': '(526)663-8919'},
#  'Aristotle Holt': {'birthday': '05/24/2053',
#   'email': 'Fusce29@mattisornare.fake.com',
#   'phone': '(686)525-6504'},
#  'Madeline Peterson': {'birthday': '11/16/2065',
#   'email': 'enim@sollicitudinadipiscingligula.superfake.com',
#   'phone': '(867)453-0089'},
#  'Rooney Riley': {'birthday': '01/09/2086',
#   'email': 'laoreet.posuere.enim@rutrumnon.fake.com',
#   'phone': '(630)805-6045'},
#  'Morgan T. Harris': {'birthday': '05/17/2095',
#   'email': None,
#   'phone': '(874)779-4778'},
#  'Daquan Holden': {'birthday': '04/18/2057',
#   'email': 'eu.tellus.eu@atlacusQuisque.org',
#   'phone': '(855)518-7318'},
#  'Moses Marquez': {'birthday': '09/14/2095',
#   'email': 'magna.a.neque@vitaemauris.org',
#   'phone': '(373)208-8286'},
#  'Kelsey L. Sparks': {'birthday': None,
#   'email': 'neque85@necurnasuscipit.superfake.com',
#   'phone': '(443)472-4020'},
#  'Herman S. Acosta': {'birthday': '12/12/2044',
#   'email': 'Nunc.lectus@Praesentinterdumligula.superfake.com',
#   'phone': '(135)725-1273'},
#  'Yasir L. Meadows': {'birthday': '09/24/2050',
#   'email': 'In.ornare72@vulputateposuerevulputate.edu',
#   'phone': '(760)849-9069'},
#  'Abbot Richardson': {'birthday': '12/10/2081',
#   'email': None,
#   'phone': '(433)261-9771'},
#  'Ayanna V. Farley': {'birthday': '02/01/2048',
#   'email': None,
#   'phone': '(353)353-1942'},
#  'Jemima Howard': {'birthday': '10/30/2054',
#   'email': 'Sed@egestasascelerisque.edu',
#   'phone': '(635)484-9444'},
#  'Mona W. Fuller': {'birthday': '08/31/2083',
#   'email': 'cursus_77@egestashendreritneque.com',
#   'phone': '(134)894-2560'},
#  'Kasper Mooney': {'birthday': '09/21/2067',
#   'email': 'pellentesque.a@nectempusmauris.net',
#   'phone': '(898)495-3759'},
#  'Ifeoma Marks': {'birthday': '11/24/2096',
#   'email': 'vel@In.superfake.com',
#   'phone': '(397)241-3559'},
#  'Amethyst N. Rivers': {'birthday': '08/20/2034',
#   'email': 'feugiat.tellus.lorem@dolor.net',
#   'phone': '(535)307-9620'},
#  'Winter F. Greene': {'birthday': None,
#   'email': 'enim.Etiam@maurisipsum.org',
#   'phone': '(707)824-4926'},
#  'Roth X. Boyle': {'birthday': '08/03/2057',
#   'email': 'elit@ametluctus.fake.com',
#   'phone': '(859)648-5111'},
#  'Baker Stafford': {'birthday': '11/17/2092',
#   'email': 'orci.Donec.nibh@aliquet.net',
#   'phone': '(185)232-4122'},
#  'Elvis F. Ramirez': {'birthday': '03/19/2093',
#   'email': 'montes.nascetur@Nullaaliquet.fake.com',
#   'phone': None},
#  'Kenyon L. Hayes': {'birthday': '11/09/2039',
#   'email': 'molestie.in@ligulaNullamfeugiat.net',
#   'phone': '(969)469-3367'},
#  'Walker Webster': {'birthday': '04/28/2085',
#   'email': 'sed.libero@ipsumdolor.net',
#   'phone': None},
#  'Hillary X. Foreman': {'birthday': '11/18/2095',
#   'email': 'orci@vulputatelacusCras.fake.com',
#   'phone': '(887)757-0679'},
#  'Sasha K. Paul': {'birthday': '08/07/2083',
#   'email': 'Vivamus.molestie.dapibus65@eu.com',
#   'phone': '(422)996-7853'},
#  'Tyrone B. Hudson': {'birthday': '01/22/2096',
#   'email': 'Phasellus@nisl.superfake.com',
#   'phone': '(828)719-0187'},
#  'Alec Dillon': {'birthday': '10/25/2046',
#   'email': 'eu.neque.pellentesque@magnaaneque.net',
#   'phone': '(148)996-0776'},
#  'Otto Z. Slater': {'birthday': '05/16/2066',
#   'email': 'montes@Vestibulumaccumsan.fake.com',
#   'phone': '(793)172-2192'},
#  'Beck Z. Compton': {'birthday': '11/14/2062',
#   'email': 'elit@arcuNunc.fake.com',
#   'phone': None},
#  'Kylynn Prince': {'birthday': '06/07/2068',
#   'email': 'varius.ultrices@Nunccommodo.superfake.com',
#   'phone': '(240)546-8006'},
#  'Kaitlin Serrano': {'birthday': '01/14/2083',
#   'email': 'ante.Vivamus@Integertincidunt.org',
#   'phone': '(160)312-9763'},
#  'Lester Hines': {'birthday': '08/17/2047',
#   'email': 'pede.sagittis.augue78@Sed.org',
#   'phone': '(818)617-6818'},
#  'Kuame Frost': {'birthday': '10/24/2046',
#   'email': 'a_36@Vestibulumaccumsan.org',
#   'phone': None},
#  'George U. Pennington': {'birthday': '06/30/2080',
#   'email': 'sit.amet@eget.org',
#   'phone': '(509)343-9385'},
#  'Adara K. Ray': {'birthday': '04/25/2057',
#   'email': 'commodo@mollisvitaeposuere.com',
#   'phone': '(209)716-8571'},
#  'Quail H. Barnes': {'birthday': '09/24/2066',
#   'email': 'cursus.Integer.mollis@egetmollis.com',
#   'phone': '(615)831-6574'},
#  'Kimberley Joyner': {'birthday': '07/01/2093',
#   'email': 'ac@ipsumdolor.fake.com',
#   'phone': None},
#  'Gillian Rodriquez': {'birthday': '09/21/2057',
#   'email': 'penatibus.et@nonjusto.org',
#   'phone': '(826)299-5332'},
#  'Brenna Henson': {'birthday': '02/07/2093',
#   'email': None,
#   'phone': '(354)115-0293'},
#  'Jasper J. Carr': {'birthday': '12/16/2090',
#   'email': 'odio@tristiqueac.edu',
#   'phone': '(511)257-2038'},
#  'Caldwell Underwood': {'birthday': '10/10/2051',
#   'email': None,
#   'phone': '(532)561-9534'},
#  'Sharon Hines': {'birthday': '04/05/2034',
#   'email': 'Etiam.laoreet.libero@liberolacus.edu',
#   'phone': '(302)930-2931'},
#  'Odessa Gilbert': {'birthday': '05/13/2050',
#   'email': 'orci.quis@nuncinterdumfeugiat.org',
#   'phone': '(197)980-0764'},
#  'Danielle Q. Guthrie': {'birthday': '12/10/2074',
#   'email': 'Nam.porttitor@Donec.superfake.com',
#   'phone': '(762)267-6944'},
#  'Duncan K. Aguirre': {'birthday': '03/23/2090',
#   'email': 'ante.ipsum.primis@diam.edu',
#   'phone': '(626)192-1632'},
#  'Tashya U. Shaw': {'birthday': '02/14/2052',
#   'email': 'Morbi@mattisInteger.com',
#   'phone': '(388)987-1946'},
#  'Ramona Dunn': {'birthday': '11/23/2043',
#   'email': 'eget.magna@at.superfake.com',
#   'phone': '(370)834-0635'},
#  'Noel Gates': {'birthday': '11/25/2044',
#   'email': 'vel.nisl_41@congueInscelerisque.fake.com',
#   'phone': '(725)291-3490'},
#  'Dexter C. Burch': {'birthday': None,
#   'email': 'justo.Praesent@facilisiSedneque.org',
#   'phone': '(111)442-2786'},
#  'Ocean G. Yates': {'birthday': '12/15/2086',
#   'email': 'pede.Nunc.sed@malesuada.fake.com',
#   'phone': '(386)728-0896'},
#  'Ruth English': {'birthday': '01/01/2095',
#   'email': None,
#   'phone': '(817)754-8620'},
#  'Rhiannon L. Whitaker': {'birthday': '04/26/2098',
#   'email': 'Etiam.bibendum44@Sed.fake.com',
#   'phone': '(638)107-1586'},
#  'Bernard Moses': {'birthday': '01/16/2100',
#   'email': 'libero.est@justositamet.org',
#   'phone': '(804)339-4136'},
#  'Steel Duke': {'birthday': '12/26/2077',
#   'email': 'cursus.vestibulum65@dolor.net',
#   'phone': '(941)930-4285'},
#  'Stephen N. Holmes': {'birthday': '06/07/2046',
#   'email': 'sagittis_53@orci.fake.com',
#   'phone': '(622)882-2882'},
#  'Emery J. Caldwell': {'birthday': '10/02/2089',
#   'email': 'sodales.at.velit@variusorciin.edu',
#   'phone': '(972)386-2609'},
#  'Burton Kirk': {'birthday': None,
#   'email': 'dui.nec@bibendumfermentum.com',
#   'phone': '(892)270-8039'},
#  'Kadeem L. Wagner': {'birthday': '04/15/2098',
#   'email': 'eu.metus.In@nonloremvitae.net',
#   'phone': None},
#  'Kyle M. Blackburn': {'birthday': '05/19/2044',
#   'email': 'et.ipsum.cursus_35@ProinvelitSed.edu',
#   'phone': '(274)705-7170'},
#  'Glenna Padilla': {'birthday': None,
#   'email': 'consequat.lectus_16@velitSed.superfake.com',
#   'phone': '(466)540-4513'},
#  'Aimee Y. King': {'birthday': '05/05/2072',
#   'email': 'vehicula.risus.Nulla@id.fake.com',
#   'phone': '(324)775-5280'},
#  'Malcolm K. Adkins': {'birthday': '06/13/2054',
#   'email': 'risus.Duis.a@feugiat.fake.com',
#   'phone': '(142)553-5944'},
#  'Jenna Calderon': {'birthday': '02/01/2042',
#   'email': 'ac@volutpatornarefacilisis.com',
#   'phone': None},
#  'Raja Nichols': {'birthday': '09/04/2044',
#   'email': 'massa.Quisque@semperegestas.org',
#   'phone': '(523)757-4034'},
#  'Daryl Olsen': {'birthday': '08/21/2060',
#   'email': 'non@velit.net',
#   'phone': '(999)183-4107'},
#  'Bertha C. Larson': {'birthday': '08/30/2098',
#   'email': 'fermentum.vel.mauris@id.superfake.com',
#   'phone': '(314)765-4572'},
#  'Gail Bell': {'birthday': '11/22/2066',
#   'email': 'sem@sed.fake.com',
#   'phone': '(190)567-8290'},
#  'Cameron Cortez': {'birthday': '09/14/2033',
#   'email': 'egestas@eratinconsectetuer.org',
#   'phone': '(877)875-7419'},
#  'Adele Foreman': {'birthday': '10/28/2056',
#   'email': 'vitae.orci.Phasellus@dictummagnaUt.edu',
#   'phone': '(832)779-3492'},
#  'Kevin Moses': {'birthday': '12/31/2034',
#   'email': 'fringilla.Donec@Suspendissealiquet.edu',
#   'phone': '(776)647-0410'},
#  'Tucker N. Garcia': {'birthday': '01/20/2094',
#   'email': 'Nunc.mauris23@nuncestmollis.fake.com',
#   'phone': '(388)721-4623'},
#  'Aaron J. Dillard': {'birthday': '05/04/2045',
#   'email': 'leo@Aenean.com',
#   'phone': '(445)335-1215'},
#  'Penelope I. Wheeler': {'birthday': '04/21/2045',
#   'email': None,
#   'phone': '(227)401-4057'},
#  'Josiah N. Wright': {'birthday': '11/30/2085',
#   'email': None,
#   'phone': '(938)610-4750'},
#  'Lars J. Hodge': {'birthday': '06/26/2042',
#   'email': 'morbi_21@eratvolutpatNulla.com',
#   'phone': '(667)110-9088'},
#  'Declan Z. Bauer': {'birthday': '06/04/2093',
#   'email': 'dictum.sapien.Aenean03@pharetraQuisqueac.net',
#   'phone': '(436)437-8544'},
#  'Marcia Sears': {'birthday': '08/04/2050',
#   'email': 'Aenean@pedenec.edu',
#   'phone': '(598)203-7467'},
#  'Kirestin N. Winters': {'birthday': '03/26/2078',
#   'email': 'enim.consequat27@pede.net',
#   'phone': '(939)334-2720'},
#  'Bruce S. Logan': {'birthday': '07/03/2048',
#   'email': 'Cras.eget.nisi@blanditmattis.superfake.com',
#   'phone': '(849)268-1687'},
# ...
#   'phone': None},
#  'Isabelle C. Carey': {'birthday': '02/17/2054',
#   'email': 'congue@porttitortellusnon.net',
#   'phone': '(996)517-1004'},
#  'Derek Curry': {'birthday': '05/06/2087',
#   'email': 'non.feugiat@atpedeCras.net',
#   'phone': '(526)157-5430'},
#  'Shad Key': {'birthday': '02/04/2050',
#   'email': 'consectetuer.adipiscing@Phasellus.net',
#   'phone': '(820)523-7599'},
#  'Aspen H. Joseph': {'birthday': '12/10/2054',
#   'email': 'enim@imperdietdictum.edu',
#   'phone': None},
#  'Gareth Sutton': {'birthday': '10/17/2093',
#   'email': 'mus@egestas.fake.com',
#   'phone': '(312)678-9637'},
#  'Quail W. Reynolds': {'birthday': '05/11/2078',
#   'email': None,
#   'phone': '(915)564-9887'},
#  'Dennis Ellison': {'birthday': '03/12/2089',
#   'email': 'semper42@ligulaAenean.net',
#   'phone': '(676)975-4690'},
#  'Zia H. Peters': {'birthday': '06/22/2072',
#   'email': 'ultrices.Duis.volutpat97@inhendrerit.org',
#   'phone': '(471)442-7620'},
#  'Lane Snow': {'birthday': '06/01/2047',
#   'email': 'Phasellus.fermentum.convallis22@rutrumeu.superfake.com',
#   'phone': '(111)378-1519'},
#  'Jeanette Lawson': {'birthday': '11/17/2075',
#   'email': 'Aliquam.ornare.libero@acfermentum.superfake.com',
#   'phone': '(384)827-3802'},
#  'Cora H. Gutierrez': {'birthday': '01/16/2033',
#   'email': 'cursus.Nunc@ridiculusmusAenean.org',
#   'phone': '(551)771-2814'},
#  'Rudyard Roman': {'birthday': '12/22/2053',
#   'email': 'metus.urna.convallis@tristiqueac.fake.com',
#   'phone': '(586)683-6961'},
#  'Sebastian M. Camacho': {'birthday': '02/17/2085',
#   'email': 'leo.elementum.sem@erosnectellus.org',
#   'phone': '(543)308-6319'},
#  'Wylie Coleman': {'birthday': '07/25/2042',
#   'email': 'diam.Proin.dolor@duinectempus.fake.com',
#   'phone': '(276)408-3560'},
#  'Tucker V. Crawford': {'birthday': '12/17/2085',
#   'email': 'et.magnis87_29@sodalespurus.superfake.com',
#   'phone': '(421)709-4480'},
#  'Gillian V. Noel': {'birthday': '01/06/2100',
#   'email': 'Fusce@non.superfake.com',
#   'phone': '(479)154-3174'},
#  'Audra B. Guerra': {'birthday': '02/20/2056',
#   'email': 'ipsum.Curabitur.consequat@lectusantedictum.org',
#   'phone': '(604)815-9589'},
#  'Hedwig G. Hensley': {'birthday': '11/21/2078',
#   'email': 'dolor.dapibus@aliquameuaccumsan.org',
#   'phone': '(176)995-6451'},
#  'Imelda Hahn': {'birthday': '09/20/2086',
#   'email': 'nec@id.edu',
#   'phone': '(858)822-3359'},
#  'Carly Rogers': {'birthday': '08/20/2040',
#   'email': 'Mauris.quis@loremvehiculaet.superfake.com',
#   'phone': '(317)307-4164'},
#  'Harper Brennan': {'birthday': '07/29/2086',
#   'email': 'nibh.lacinia.orci_09@leoMorbi.com',
#   'phone': '(218)467-0159'},
#  'Aline Frank': {'birthday': '11/22/2069',
#   'email': 'tincidunt.vehicula.risus_66@Etiam.superfake.com',
#   'phone': '(376)601-0923'},
#  'Patience R. Hart': {'birthday': '04/05/2043',
#   'email': 'ac.ipsum@ametluctus.net',
#   'phone': '(705)288-3489'},
#  'Darrel Brock': {'birthday': '02/20/2042',
#   'email': None,
#   'phone': '(998)234-8074'},
#  'Jeremy Mooney': {'birthday': '04/19/2040',
#   'email': 'vitae.risus00@Integer.edu',
#   'phone': '(393)621-8841'},
#  'Francis W. Winters': {'birthday': '01/28/2060',
#   'email': 'magna@nonfeugiat.com',
#   'phone': None},
#  'Belle Strong': {'birthday': '11/03/2057',
#   'email': 'lacus_85@Nullamvelitdui.superfake.com',
#   'phone': '(668)210-4552'},
#  'Trevor Kline': {'birthday': '08/20/2039',
#   'email': 'risus.Morbi.metus@Praesentluctus.fake.com',
#   'phone': '(586)191-9386'},
#  'Azalia W. Savage': {'birthday': '10/15/2089',
#   'email': 'ultrices@eutelluseu.superfake.com',
#   'phone': '(823)854-2322'},
#  'Adara M. Day': {'birthday': '10/20/2076',
#   'email': 'Aenean@mauris.fake.com',
#   'phone': '(469)495-9923'},
#  'Felicia Hurley': {'birthday': '07/19/2044',
#   'email': 'tempus.risus@eu.fake.com',
#   'phone': '(123)289-5855'},
#  'Jermaine Compton': {'birthday': '10/25/2061',
#   'email': 'urna.suscipit.nonummy@lectuspedeet.org',
#   'phone': '(178)361-3364'},
#  'Amanda Curry': {'birthday': '02/21/2041',
#   'email': 'est@volutpatNullafacilisis.org',
#   'phone': '(413)817-3046'},
#  'Vanna T. Bryan': {'birthday': None,
#   'email': 'Aliquam.erat@magnamalesuadavel.edu',
#   'phone': '(770)253-8899'},
#  'Kaitlin N. Mcgowan': {'birthday': '04/09/2083',
#   'email': 'sem@auctornunc.fake.com',
#   'phone': '(926)362-3969'},
#  'Margaret Crane': {'birthday': '12/13/2074',
#   'email': None,
#   'phone': '(350)234-2320'},
#  'Iliana Wooten': {'birthday': '07/13/2088',
#   'email': 'cursus.in.hendrerit97@magna.org',
#   'phone': '(653)546-6852'},
#  'Ifeoma Mcmahon': {'birthday': '01/03/2041',
#   'email': 'parturient@FuscemollisDuis.superfake.com',
#   'phone': '(245)873-4945'},
#  'Malachi Peterson': {'birthday': '10/17/2082',
#   'email': 'lectus@felis.net',
#   'phone': '(482)907-7205'},
#  'Howard Park': {'birthday': '02/24/2084',
#   'email': 'sem.molestie79@consequatnec.com',
#   'phone': '(160)424-8118'},
#  'Brandon Benson': {'birthday': None,
#   'email': 'cursus.et.eros@arcu.org',
#   'phone': '(412)958-8838'},
#  'Aileen U. Vaughn': {'birthday': '09/10/2057',
#   'email': None,
#   'phone': '(792)472-9668'},
#  'Jena Beard': {'birthday': '01/06/2067',
#   'email': 'lorem.tristique.aliquet72@lobortisauguescelerisque.net',
#   'phone': '(947)353-3385'},
#  'Carly Barnett': {'birthday': '01/09/2084',
#   'email': 'morbi.tristique.senectus@loremac.fake.com',
#   'phone': '(312)322-0180'},
#  'Freya Sutton': {'birthday': '12/04/2069',
#   'email': 'ipsum@nequeSedeget.com',
#   'phone': '(282)190-9655'},
#  'Jordan H. Hunt': {'birthday': '07/28/2072',
#   'email': 'lacus.varius@mauriseuelit.com',
#   'phone': '(214)709-6207'},
#  'Caesar P. Herring': {'birthday': '01/11/2049',
#   'email': 'at.fringilla.purus@Praesenteu.superfake.com',
#   'phone': '(698)786-1507'},
#  'Helen Y. Strickland': {'birthday': '11/13/2063',
#   'email': 'vestibulum@ultricesposuere.fake.com',
#   'phone': '(856)917-6475'},
#  'Nelle X. Frye': {'birthday': None,
#   'email': 'sed.est_83@sed.fake.com',
#   'phone': '(698)860-1526'},
#  'Candice V. Wolfe': {'birthday': '07/28/2049',
#   'email': 'nisi@diamSeddiam.com',
#   'phone': '(490)826-1365'},
#  'Daquan K. Reed': {'birthday': '11/04/2099',
#   'email': 'Nulla.eu@tincidunt.edu',
#   'phone': '(788)708-6751'},
#  'Sandra Cochran': {'birthday': '12/11/2034',
#   'email': 'ac17@etmagnisdis.com',
#   'phone': '(232)790-2929'},
#  'Carissa Silva': {'birthday': '05/31/2090',
#   'email': 'magna.Nam@quis.superfake.com',
#   'phone': '(480)791-6465'},
#  'Rylee L. Gould': {'birthday': '04/27/2074',
#   'email': 'Morbi.neque@Suspendisse.org',
#   'phone': '(124)195-3596'},
#  'Carter V. Barrera': {'birthday': '08/21/2079',
#   'email': None,
#   'phone': '(104)145-1121'},
#  'Dieter Becker': {'birthday': '11/06/2041',
#   'email': 'ante@orciin.fake.com',
#   'phone': '(613)338-0406'},
#  'Berk Moore': {'birthday': '11/13/2079',
#   'email': 'magna.Lorem@cursus.com',
#   'phone': '(118)693-2072'},
#  'Burton Barnett': {'birthday': '10/12/2065',
#   'email': 'dui@vulputate.com',
#   'phone': '(952)986-2095'},
#  'Natalie Moreno': {'birthday': '10/22/2079',
#   'email': 'fringilla.cursus@maurisaliquam.org',
#   'phone': '(664)571-5062'},
#  'Len Pena': {'birthday': '10/05/2035',
#   'email': 'ac.facilisis@NullamenimSed.org',
#   'phone': '(989)404-9968'},
#  'Joan Y. Frazier': {'birthday': '01/28/2045',
#   'email': 'tristique.aliquet.Phasellus@arcu.org',
#   'phone': '(758)867-6171'},
#  'Sean R. Herman': {'birthday': '11/04/2039',
#   'email': 'lorem@Innec.superfake.com',
#   'phone': '(269)992-8252'},
#  'Blythe Battle': {'birthday': '02/14/2091',
#   'email': 'Suspendisse.commodo@ipsumSuspendisse.com',
#   'phone': '(331)242-0927'},
#  'Lenore L. Mendoza': {'birthday': '04/27/2081',
#   'email': 'dolor.quam@Nulla.fake.com',
#   'phone': '(120)819-7677'},
#  'Lenore K. Sweeney': {'birthday': '11/30/2065',
#   'email': 'elementum@Donec.net',
#   'phone': '(191)230-7207'},
#  'Alec Galloway': {'birthday': '10/31/2033',
#   'email': 'massa.non.ante@fringillaeuismod.edu',
#   'phone': '(248)354-4475'},
#  'Julian Simpson': {'birthday': '11/10/2062',
#   'email': 'sed.hendrerit.a77@sapiencursus.com',
#   'phone': '(975)609-1686'},
#  'Vladimir S. Mcclure': {'birthday': '05/13/2089',
#   'email': 'luctus.et@lacus.com',
#   'phone': '(946)470-1156'},
#  'Andrew U. Ochoa': {'birthday': '02/28/2086',
#   'email': 'amet.lorem.semper@eu.org',
#   'phone': '(717)747-8440'},
#  'Kiara P. Gray': {'birthday': '02/06/2099',
#   'email': 'lacus.Aliquam@tinciduntduiaugue.fake.com',
#   'phone': '(136)989-4825'},
#  'Marny Jordan': {'birthday': '07/21/2033',
#   'email': 'egestas@Fuscemollis.superfake.com',
#   'phone': '(831)990-9648'},
#  'Murphy Wade': {'birthday': '10/14/2068',
#   'email': 'erat.Sed@aliquetlobortis.fake.com',
#   'phone': '(906)894-2038'},
#  'Blaze D. Elliott': {'birthday': '07/31/2032',
#   'email': 'Fusce@metus.net',
#   'phone': '(274)233-2734'},
#  'Jonas Stevens': {'birthday': '05/30/2081',
#   'email': 'erat.volutpat.Nulla@ligulaeuenim.com',
#   'phone': '(891)295-1676'},
#  'Minerva Foreman': {'birthday': '06/27/2082',
#   'email': 'dignissim.pharetra@porttitorscelerisque.fake.com',
#   'phone': '(815)749-5432'},
#  'Fritz Romero': {'birthday': '03/14/2046',
#   'email': 'nisi.sem@orciUtsemper.org',
#   'phone': '(891)698-1916'},
#  'Brian Valdez': {'birthday': '07/10/2057',
#   'email': 'sodales.at.velit@natoquepenatibuset.fake.com',
#   'phone': '(778)631-4875'},
#  'Theodore J. Bryan': {'birthday': '10/16/2048',
#   'email': 'eleifend@eueleifendnec.fake.com',
#   'phone': '(299)119-2342'},
#  'Skyler Stanton': {'birthday': '11/22/2085',
#   'email': 'libero@imperdietullamcorperDuis.superfake.com',
#   'phone': '(139)155-9570'},
#  'Reagan C. Shields': {'birthday': '03/25/2091',
#   'email': 'felis.eget@tincidunt.superfake.com',
#   'phone': '(581)504-9366'},
#  'Keelie Carr': {'birthday': '06/18/2058',
#   'email': 'sem.consequat@arcu.org',
#   'phone': '(374)627-0663'},
#  'Curran U. Chandler': {'birthday': None,
#   'email': None,
#   'phone': '(566)218-6873'},
#  'Wyoming Hubbard': {'birthday': '05/10/2086',
#   'email': 'odio.Nam.interdum@Phasellus.org',
#   'phone': '(918)690-1015'},
#  'Mara D. Mills': {'birthday': '05/21/2054',
#   'email': 'sem.consequat@dignissimmagna.com',
#   'phone': '(834)926-3124'},
#  'Noelani K. Burgess': {'birthday': '07/28/2053',
#   'email': 'tempus.lorem.fringilla@ut.fake.com',
#   'phone': '(737)922-8850'},
#  'Yolanda Burch': {'birthday': '01/13/2045',
#   'email': 'Praesent.luctus.Curabitur@faucibusorciluctus.com',
#   'phone': '(772)223-0500'},
#  'Noelani T. Griffith': {'birthday': '02/22/2081',
#   'email': 'arcu@egetvolutpatornare.edu',
#   'phone': '(460)536-0472'},
#  'Ishmael Stephens': {'birthday': '05/20/2061',
#   'email': 'consequat.nec.mollis@nullaat.superfake.com',
#   'phone': '(816)909-0523'},
#  'Sierra Bowers': {'birthday': '04/23/2062',
#   'email': 'eu23@condimentumegetvolutpat.net',
#   'phone': '(744)685-5447'},
#  'Bell B. Black': {'birthday': '05/14/2072',
#   'email': 'vitae.diam_32@Fuscealiquam.com',
#   'phone': '(894)958-9037'},
#  'Patience Golden': {'birthday': '03/03/2050',
#   'email': 'vel.est.tempor@dolor.superfake.com',
#   'phone': None},
#  'Brennan B. Cleveland': {'birthday': '01/13/2077',
#   'email': 'consequat.dolor.vitae@accumsanlaoreet.org',
#   'phone': '(943)666-4239'},
#  'Gage Albert': {'birthday': '07/29/2082',
#   'email': None,
#   'phone': '(999)705-3880'},
#  'Colleen H. Barrera': {'birthday': '11/15/2080',
#   'email': 'diam.dictum.sapien@augue.superfake.com',
#   'phone': '(786)762-5164'},
#  'Keegan K. Colon': {'birthday': '03/06/2084',
#   'email': 'dis42@posuerecubiliaCurae.net',
#   'phone': '(484)799-1762'},
#  'Carolyn F. Dale': {'birthday': '10/26/2081',
#   'email': 'lectus.sit@odioAliquamvulputate.superfake.com',
#   'phone': '(164)176-3824'},
#  'Ethan Berg': {'birthday': '10/21/2092',
#   'email': 'ipsum@non.net',
#   'phone': '(744)621-3089'},
#  'Lyle V. Riddle': {'birthday': '08/03/2095',
#   'email': 'mauris.ut_67@sapienAeneanmassa.net',
#   'phone': '(259)311-0271'},
#  'Demetrius Barry': {'birthday': '08/23/2040',
#   'email': 'felis.Donec.tempor@eunibh.org',
#   'phone': '(399)733-5982'},
#  'Honorato Davis': {'birthday': None,
#   'email': 'non@justoPraesentluctus.superfake.com',
#   'phone': '(386)983-8487'},
#  'Alfonso Davidson': {'birthday': '05/08/2094',
#   'email': 'pretium80@dignissimmagna.fake.com',
#   'phone': '(263)970-8463'},
#  'Rashad B. Morrow': {'birthday': '11/28/2062',
#   'email': 'aliquet_01@enim.fake.com',
#   'phone': '(811)149-0001'},
#  'Karleigh Francis': {'birthday': '12/08/2089',
#   'email': 'consequat@nec.net',
#   'phone': '(339)945-0684'},
#  'Michael C. Valentine': {'birthday': None,
#   'email': None,
#   'phone': '(990)671-2911'},
#  'Scarlett R. Humphrey': {'birthday': None,
#   'email': 'Nulla@elitfermentum.fake.com',
#   'phone': '(553)897-8699'},
#  'Candace Cooke': {'birthday': '11/05/2051',
#   'email': 'ligula.eu@dolor.superfake.com',
#   'phone': '(358)326-1373'},
#  'Delilah I. Hester': {'birthday': '11/07/2066',
#   'email': None,
#   'phone': '(157)448-2916'},
#  'Chaim M. Atkins': {'birthday': '04/01/2057',
#   'email': 'Phasellus@vestibulum.com',
#   'phone': '(585)283-3398'},
#  'Carter V. Arnold': {'birthday': '11/23/2055',
#   'email': 'Integer.eu@sem.org',
#   'phone': '(940)688-1884'},
#  'Cynthia U. Rivas': {'birthday': '06/27/2066',
#   'email': 'dui.nec_04@semperpretiumneque.superfake.com',
#   'phone': '(947)829-7121'},
#  'Quentin Simon': {'birthday': '12/30/2044',
#   'email': 'ipsum.sodales.purus@Namtempordiam.fake.com',
#   'phone': '(539)932-6855'},
#  'Lawrence Alvarez': {'birthday': '01/18/2043',
#   'email': None,
#   'phone': '(236)877-6069'},
#  'Fay H. Joseph': {'birthday': '04/03/2067',
#   'email': 'sed.dui_72@rutrumurnanec.fake.com',
#   'phone': '(278)488-8058'},
#  'Tad H. Knox': {'birthday': '08/05/2065',
#   'email': 'orci.tincidunt.adipiscing@Donec.superfake.com',
#   'phone': '(154)855-3360'},
#  'Rowan Howell': {'birthday': '09/10/2040',
#   'email': 'Pellentesque.habitant@duiquis.net',
#   'phone': '(328)791-8357'},
#  'Madonna Potts': {'birthday': '01/24/2057',
#   'email': 'placerat.augue.Sed@semmagna.net',
#   'phone': '(960)642-9362'},
#  'Brody W. Weiss': {'birthday': None,
#   'email': 'justo.Proin.non@dui.fake.com',
#   'phone': '(703)983-7401'},
#  'Joelle Holland': {'birthday': '04/21/2100',
#   'email': 'ipsum.ac.mi@enimgravida.fake.com',
#   'phone': '(818)669-3485'},
#  'Ariel R. Roth': {'birthday': '03/03/2090',
#   'email': 'venenatis.a.magna@metus.edu',
#   'phone': '(710)243-5871'},
#  'Harriet O. Allen': {'birthday': '09/22/2091',
#   'email': 'aptent@ultricies.superfake.com',
#   'phone': '(940)478-7151'},
#  'Richard Nguyen': {'birthday': '10/05/2075',
#   'email': 'ipsum_07@libero.fake.com',
#   'phone': '(927)262-1484'},
#  'Porter W. Guerrero': {'birthday': '03/21/2085',
#   'email': 'convallis@auctor.superfake.com',
#   'phone': '(584)327-8975'},
#  'Cheryl D. Soto': {'birthday': '02/04/2075',
#   'email': 'adipiscing@PhasellusnullaInteger.com',
#   'phone': '(389)778-5474'},
#  'Claire Kinney': {'birthday': '08/05/2067',
#   'email': 'felis99@dui.fake.com',
#   'phone': '(988)715-1813'},
#  'Marcia V. Marsh': {'birthday': '09/30/2065',
#   'email': 'egestas.Aliquam.fringilla_14@pellentesqueafacilisis.edu',
#   'phone': '(434)761-3538'},
#  'Kylynn T. Norman': {'birthday': '01/09/2100',
#   'email': 'ac.turpis@nuncsit.superfake.com',
#   'phone': '(635)664-6734'},
#  'Lucy Y. Landry': {'birthday': '06/26/2039',
#   'email': 'egestas.nunc.sed@CurabiturdictumPhasellus.superfake.com',
#   'phone': '(230)500-6712'},
#  'Tallulah R. Long': {'birthday': '10/14/2079',
#   'email': 'tellus.imperdiet@augueut.superfake.com',
#   'phone': '(273)632-9124'},
#  'Azalia Carr': {'birthday': '11/19/2058',
#   'email': 'tincidunt.nunc.ac@feugiat.org',
#   'phone': '(277)303-0752'},
#  'Morgan N. Oneal': {'birthday': '08/01/2087',
#   'email': 'est.Mauris@Seddiamlorem.edu',
#   'phone': None},
#  'Zachary Benton': {'birthday': '03/06/2048',
#   'email': 'a.ultricies78@odio.net',
#   'phone': '(524)294-0308'},
#  'Uriah Workman': {'birthday': '12/10/2049',
#   'email': 'Aliquam.auctor@vel.com',
#   'phone': '(873)996-5622'},
#  'Remedios T. Clarke': {'birthday': '12/29/2058',
#   'email': 'Vestibulum@parturientmontesnascetur.net',
#   'phone': '(183)192-2631'},
#  'Phyllis J. Herman': {'birthday': '04/06/2044',
#   'email': 'ridiculus.mus@Pellentesquehabitantmorbi.edu',
#   'phone': '(939)580-8241'},
#  ...}
